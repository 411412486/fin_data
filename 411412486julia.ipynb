# %%
using Pkg
Pkg.add("CSV")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SentinelArrays ────────────── v1.4.1
#    Installed DataAPI ───────────────────── v1.15.0
#    Installed PooledArrays ──────────────── v1.4.3
#    Installed TableTraits ───────────────── v1.0.1
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed InlineStrings ─────────────── v1.4.0
#    Installed Tables ────────────────────── v1.11.1
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed WorkerUtilities ───────────── v1.6.1
#    Installed WeakRefStrings ────────────── v1.4.2
#    Installed Compat ────────────────────── v4.10.1
#    Installed CodecZlib ─────────────────── v0.7.3
#    Installed TranscodingStreams ────────── v0.10.2
#    Installed OrderedCollections ────────── v1.6.3
#    Installed FilePathsBase ─────────────── v0.9.21
#    Installed CSV ───────────────────────── v0.10.12
#     Updating `~/.julia/environments/v1.10/Project.toml`
# ...

# %%
using CSV

# %%
using DataFrames
# Out:
# ArgumentError: Package DataFrames not found in current path.
# - Run `import Pkg; Pkg.add("DataFrames")` to install the DataFrames package.
#
# Stacktrace:
#  [1] macro expansion
#    @ Base ./loading.jl:1766 [inlined]
#  [2] macro expansion
#    @ Base ./lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1747
#  [4] #invoke_in_world#3
#    @ Base ./essentials.jl:921 [inlined]
#  [5] invoke_in_world
#    @ Base ./essentials.jl:918 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1740

# %%
import Pkg; Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#    Installed Crayons ──────────── v4.1.1
#    Installed LaTeXStrings ─────── v1.3.1
#    Installed Reexport ─────────── v1.2.2
#    Installed InvertedIndices ──── v1.3.0
#    Installed Missings ─────────── v1.1.0
#    Installed StringManipulation ─ v0.3.4
#    Installed SortingAlgorithms ── v1.2.1
#    Installed DataFrames ───────── v1.6.1
#    Installed DataStructures ───── v0.18.16
#    Installed PrettyTables ─────── v2.3.1
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [a93c6f00] + DataFrames v1.6.1
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.6.1
#   [864edb3b] + DataStructures v0.18.16
#   [41ab1584] + InvertedIndices v1.3.0
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [e1d29d7a] + Missings v1.1.0
#   [08abe8d2] + PrettyTables v2.3.1
#   [189a3867] + Reexport v1.2.2
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [892a3eda] + StringManipulation v0.3.4
# ...

# %%
using DataFrames
csv_reader = CSV.File("/Users/Chi/Downloads/new.csv")
df = DataFrame(csv_reader)
# Out:
# 13268×115 DataFrame
#    Row │ iso3     iso2     imfn   country   region                     income  ⋯
#        │ String3  String3  Int64  String31  String31                   String3 ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in ⋯
#      2 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
#      3 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
#      4 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
#      5 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in ⋯
#      6 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
#      7 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
#      8 │ ABW      AW         314  Aruba     Latin America & Caribbean  High in
# ...

# %%
describe(df)
# Out:
# 115×7 DataFrame
#  Row │ variable  mean       min                  median  max                   ⋯
#      │ Symbol    Union…     Any                  Union…  Any                   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ iso3                 ABW                          ZWE                   ⋯
#    2 │ iso2                 AD                           zz
#    3 │ imfn      576.893    111                  613.0   1012
#    4 │ country              Afghanistan                  Zimbabwe
#    5 │ region               East Asia & Pacific          Sub-Saharan Africa    ⋯
#    6 │ income               High income                  Upper middle income
#    7 │ year      1990.5     1960                 1990.5  2021
#    8 │ ai01      2689.46    0.0                  473.06  2.73254e5
#    9 │ ai02      31.4911    0.14                 13.795  1784.2                ⋯
#   10 │ ai03      34.4882    2.7                  35.45   79.6
# ...

# %%
gdf = groupby(df, :income) #更改為你自己的類別變數
gdf_summary = combine(gdf, nrow)
# Out:
# 4×2 DataFrame
#  Row │ income               nrow
#      │ String31             Int64
# ─────┼────────────────────────────
#    1 │ High income           4898
#    2 │ Low income            1674
#    3 │ Lower middle income   3348
#    4 │ Upper middle income   3348

# %%
using StatsPlots
# Out:
# ArgumentError: Package StatsPlots not found in current path.
# - Run `import Pkg; Pkg.add("StatsPlots")` to install the StatsPlots package.
#
# Stacktrace:
#  [1] macro expansion
#    @ Base ./loading.jl:1766 [inlined]
#  [2] macro expansion
#    @ Base ./lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1747
#  [4] #invoke_in_world#3
#    @ Base ./essentials.jl:921 [inlined]
#  [5] invoke_in_world
#    @ Base ./essentials.jl:918 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1740

# %%
import Pkg; Pkg.add("StatsPlots")
# Out:
#    Resolving package versions...
#    Installed Calculus ───────────────────── v0.5.1
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed LERC_jll ───────────────────── v3.0.0+1
#    Installed libfdk_aac_jll ─────────────── v2.0.2+0
#    Installed JpegTurbo_jll ──────────────── v3.0.1+0
#    Installed StatsFuns ──────────────────── v1.3.0
#    Installed GR_jll ─────────────────────── v0.72.10+0
#    Installed Libmount_jll ───────────────── v2.35.0+0
#    Installed Opus_jll ───────────────────── v1.3.2+0
#    Installed OffsetArrays ───────────────── v1.13.0
#    Installed LoggingExtras ──────────────── v1.0.3
#    Installed HypergeometricFunctions ────── v0.3.23
#    Installed FFTW ───────────────────────── v1.7.2
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Unitful ────────────────────── v1.19.0
#    Installed Measures ───────────────────── v0.3.2
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.6+0
# ...

# %%
using StatsPlots

# %%
gdf = groupby(df, :income) #更改為你自己的類別變數
gdf_summary = combine(gdf, nrow)
# Out:
# 4×2 DataFrame
#  Row │ income               nrow
#      │ String31             Int64
# ─────┼────────────────────────────
#    1 │ High income           4898
#    2 │ Low income            1674
#    3 │ Lower middle income   3348
#    4 │ Upper middle income   3348

# %%
gdf_summary
# Out:
# 4×2 DataFrame
#  Row │ income               nrow
#      │ String31             Int64
# ─────┼────────────────────────────
#    1 │ High income           4898
#    2 │ Low income            1674
#    3 │ Lower middle income   3348
#    4 │ Upper middle income   3348

# %%
bar(gdf_summary[!, :nrow], xticks=(1:4, gdf_summary[!, :income]),labels="freq")#  1:4 的4代表類別的個數，可參考describe(df)

# %%
using CategoricalArrays
# Out:
# ArgumentError: Package CategoricalArrays not found in current path.
# - Run `import Pkg; Pkg.add("CategoricalArrays")` to install the CategoricalArrays package.
#
# Stacktrace:
#  [1] macro expansion
#    @ Base ./loading.jl:1766 [inlined]
#  [2] macro expansion
#    @ Base ./lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1747
#  [4] #invoke_in_world#3
#    @ Base ./essentials.jl:921 [inlined]
#  [5] invoke_in_world
#    @ Base ./essentials.jl:918 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1740

# %%
import Pkg; Pkg.add("CategoricalArrays")
# Out:
#    Resolving package versions...
#    Installed CategoricalArrays ─ v0.10.8
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [324d7699] + CategoricalArrays v0.10.8
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [324d7699] + CategoricalArrays v0.10.8
# Precompiling project...
#   ✓ CategoricalArrays
#   ✓ CategoricalArrays → CategoricalArraysRecipesBaseExt
#   ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#   ✓ CategoricalArrays → CategoricalArraysJSONExt
#   4 dependencies successfully precompiled in 4 seconds. 233 already precompiled.

# %%
using CategoricalArraysusing Statistics
# Out:
# ArgumentError: Package CategoricalArraysusing not found in current path.
# - Run `import Pkg; Pkg.add("CategoricalArraysusing")` to install the CategoricalArraysusing package.
#
# Stacktrace:
#  [1] macro expansion
#    @ Base ./loading.jl:1766 [inlined]
#  [2] macro expansion
#    @ Base ./lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1747
#  [4] #invoke_in_world#3
#    @ Base ./essentials.jl:921 [inlined]
#  [5] invoke_in_world
#    @ Base ./essentials.jl:918 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1740

# %%
using CategoricalArrays
using Statistics

# %%
ai01_edge = 0:100:1000000
# Out:
# 0:100:1000000

# %%
df.ai01_bin = cut(df[!,:ai01], ai01_edge)
# Out:
# 13268-element CategoricalArray{Union{Missing, String},1,UInt32}:
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  ⋮
#  "[100, 200)"
#  "[0, 100)"
#  "[0, 100)"
#  "[0, 100)"
#  "[100, 200)"
#  "[0, 100)"
#  "[200, 300)"
#  "[400, 500)"
#  "[500, 600)"
#  "[600, 700)"
#  "[500, 600)"
#  missing

# %%
combine(groupby(df, :ai01_bin), nrow)
# Out:
# 49×2 DataFrame
#  Row │ ai01_bin          nrow
#      │ Cat…?             Int64
# ─────┼─────────────────────────
#    1 │ missing           11860
#    2 │ [0, 100)            266
#    3 │ [100, 200)          180
#    4 │ [200, 300)          123
#    5 │ [300, 400)           90
#    6 │ [400, 500)           60
#    7 │ [500, 600)           72
#    8 │ [600, 700)           98
#    9 │ [700, 800)           80
#   10 │ [800, 900)           43
#   11 │ [900, 1000)          68
#   ⋮  │        ⋮            ⋮
#   40 │ [137100, 137200)      2
#   41 │ [148300, 148400)      1
#   42 │ [166000, 166100)      1
#   43 │ [191700, 191800)      1
#   44 │ [206400, 206500)      1
#   45 │ [218900, 219000)      1
#   46 │ [223900, 224000)      1
#   47 │ [238600, 238700)      1
#   48 │ [254400, 254500)      1
#   49 │ [273200, 273300)      1
#                 28 rows omitted

# %%
ai02_edge = 0:50:2000
# Out:
# 0:50:2000

# %%
df.ai02_bin = cut(df[!,:ai02], ai02_edge)
# Out:
# 13268-element CategoricalArray{Union{Missing, String},1,UInt32}:
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  missing
#  ⋮
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  "[0, 50)"
#  missing

# %%
combine(groupby(df, :ai02_bin), nrow)
# Out:
# 20×2 DataFrame
#  Row │ ai02_bin      nrow
#      │ Cat…?         Int64
# ─────┼─────────────────────
#    1 │ missing       10260
#    2 │ [0, 50)        2775
#    3 │ [50, 100)       155
#    4 │ [100, 150)       10
#    5 │ [150, 200)       18
#    6 │ [200, 250)       15
#    7 │ [250, 300)        2
#    8 │ [300, 350)        2
#    9 │ [350, 400)        2
#   10 │ [400, 450)        3
#   11 │ [450, 500)        3
#   12 │ [500, 550)        5
#   13 │ [1400, 1450)      3
#   14 │ [1450, 1500)      2
#   15 │ [1500, 1550)      2
#   16 │ [1550, 1600)      3
#   17 │ [1600, 1650)      2
#   18 │ [1650, 1700)      1
#   19 │ [1700, 1750)      2
#   20 │ [1750, 1800)      3

# %%
using Plots
# Out:
# ArgumentError: Package Plots not found in current path, maybe you meant `import/using .Plots`.
# - Otherwise, run `import Pkg; Pkg.add("Plots")` to install the Plots package.
#
# Stacktrace:
#  [1] macro expansion
#    @ Base ./loading.jl:1766 [inlined]
#  [2] macro expansion
#    @ Base ./lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1747
#  [4] #invoke_in_world#3
#    @ Base ./essentials.jl:921 [inlined]
#  [5] invoke_in_world
#    @ Base ./essentials.jl:918 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1740

# %%
import Pkg; Pkg.add("Plots")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [91a5bcdd] + Plots v1.39.0
#   No Changes to `~/.julia/environments/v1.10/Manifest.toml`

# %%
b_range = range(0, 1000, length=10)
# Out:
# 0.0:111.11111111111111:1000.0

# %%
histogram(df[!,:ai01],bins=b_range)

# %%
histogram(df[!,:ai01],bins=b_range, normalize=:pdf)

# %%
b_range = range(0, 100, length=21)
# Out:
# 0.0:5.0:100.0

# %%
histogram(df[!,:ai02],bins=b_range)

# %%
histogram(df[!,:ai02],bins=b_range, normalize=:pdf)
xlims!(0, 50)

# %%
using Plots

# %%
scatter(df[!,:ai01], df[!,:ai02])

# %%
scatter(df[!,:ai01], df[!,:ai02])
xlims!(0, 100)
ylims!(0, 1)

# %%
scatter(df[!,:ai03], df[!,:ai04])
